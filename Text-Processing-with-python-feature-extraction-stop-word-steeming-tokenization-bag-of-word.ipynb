# %%
import pandas as pd
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import word_tokenize

# Assign spreadsheet filename to `file`
data='F:/DS/H/respon.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(data)

# Print the sheet names
#print(xl.sheet_names)

# Load a sheet into a DataFrame by name: df1
#df1 = xl.parse('Pertanyaan 1', skiprows=1)
#df1 = xl.parse('Pertanyaan 3', skiprows=1)
#df1 = xl.parse('Pertanyaan 4')
#df1 = xl.parse('Pertanyaan 7')
#df1 = xl.parse('Pertanyaan 8')
#df1 = xl.parse('Pertanyaan 10')

print(df1.Jawaban)
# Out:
# 0                               DI BAGIAN KUTUB SELATAN
# 1                    YANG PALING DINGIN DI KUTUB SELATAN
# 2                                      DI KUTUB SELATAN
# 3           KUTUB SELATAN TEPATNYA ADA DI TENGAH TENGAH
# 4                                         KUTUB SELATAN
# 5                                         KUTUB SELATAN
# 6                                      DI KUTUB SELATAN
# 7                                       DI KUTUB SELATAN
# 8                                         KUTUB SELATAN
# 9      KUTUB SELATAN SUHU RATA-RATA PADA BULAN JANUAR...
# 10                     BERADA DI TENGAH-TENGAH ANTARTIKA
# 11                                      DI KUTUB SELATAN
# 12     ANTARIKA ADALAH BENUA YG TERDINGIN, TERKERING,...
# 13                                      DI KUTUB SELATAN
# 14                                ALDAH DI KUTUP SELATAN
# 15                                         KUTUP SELATAN
# 16                                         KUTUB SELATAN
# 17                                      DI KUTUB SELATAN
# 18                                    BASAH DAN BERANGIN
# 19                                      DI KUTUB SELATAN
# 20                                         KUTUP SELATAN
# 21     YAITU BULAN APRIL SAMPAI SEPTEMBER KEJADIAN SE...
# 22                                                 BLANK
# 23                                      DI KUTUB SELATAN
# 24     KUTUK SELATAN TEPATNYA BERADA DI TENGAH TENGAH...
# 25                                      DI KUTUB SELATAN
# 26                                        KUTUB SELATAN
# 27     ANTARTIKA SELALU DINGIN DARIPADA APA YG KITA B...
# 28                                         KUTUB SELATAN
# 29                                         KUTUB SELATAN
#                              ...
# 583                             DI BAGIAN KUTUB SELATAN
# 584                                       KUTUB SELATAN
# 585                                BAGIAN KUTUB SELATAN
# 586    DI ANTARTIKA SELALU LEBIH DINGIN DARIPADA APA ...
# 587    DI KUTUB SELATAN SUHU RATA RATA DI TENGAH MUSI...
# 588    KUTUB SELATAN SUHU RATA RATA PADA BULAN JANUAR...
# 589                                       KUTUB SELATAN
# 590                                       KUTUB SELATAN
# 591                 TEPATNYA DI TENGAH TENGAH ANTARTIKA
# 592                                     DI KUTUB SELATAN
# 593    BAGIAN YANG PALING DINGIN ADALAH DI KUTUB SELATAN
# 594                                        KUTUB SELATAN
# 595           YANG PALING DINGIN ADALAH DI KUTUB SELATAN
# 596                                    DI KUTUB SELATAN
# 597                                        KUTUB SELATAN
# 598                                     DI KUTUB SELATAN
# 599                     KUTUB SELATAN YANG PALING DINGIN
# 600    KUTUB SELATAN SUHU RATA-RATA DI TULIS PADA DI ...
# 601                                     DI KUTUB SELATAN
# 602                                      DIKUTUB SELATAN
# 603                                      DIKUTUB SELATAN
# 604                                        KUTUB SELATAN
# 605                                   DI SEBELAH SELATAN
# 606             SELURUH PERMUKAAN BUMI DAN DISELIMUTI ES
# 607              YANG PALING DINGIN ADALAH KUTUB SELATAN
# 608                                     DIKUTUB SELATAN
# 609             KUTUB SELATAN DI TENGAH TENGAH ANTARTIKA
# 610                               BERADA DIKUTUB SELATAN
# 611                                        KUTUB SELATAN
# 612    KUTUB SELATATAN TEMPATNYA BERADA DITENGAH-TENG...
# Name: Jawaban, Length: 613, dtype: object

# %%
#emptyarray for pre-processing
stopsheet1=[]
steemsheet1=[]

# %%
#select coloum jawaban
sheet1 = df1.Jawaban

#stopword
 
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
#print(stopwords)

#lowercase
sheet1=sheet1.str.lower()
#print(type(sheet1))

sheetray=sheet1.tolist()
print(sheetray)

#print(type(sheet1))
#print(sheet1[1])
# Out:
# ['di bagian kutub selatan ', 'yang paling dingin di kutub selatan', 'di kutub selatan ', 'kutub selatan tepatnya ada di tengah tengah ', 'kutub selatan ', 'kutub selatan ', 'di kutub selatan ', 'di kutub selatan', 'kutub selatan ', 'kutub selatan suhu rata-rata pada bulan januari di tengah-tengah musim panas adalah -28 derajat celcius', 'berada di tengah-tengah antartika', 'di kutub selatan', 'antarika adalah benua yg terdingin, terkering, tertinggi', 'di kutub selatan', 'aldah di kutup selatan', 'kutup selatan', 'kutub selatan', 'di kutub selatan', 'basah dan berangin', 'di kutub selatan', 'kutup selatan', 'yaitu bulan april sampai september kejadian sebaliknya terjadi', 'blank', 'di kutub selatan', 'kutuk selatan tepatnya berada di tengah tengah antartika', 'di kutub selatan', 'kutub selatan ', 'antartika selalu dingin daripada apa yg kita bayangkan termasuk pada musim panas pada bagian baah', 'kutub selatan', 'kutub selatan', 'kutub selatan', 'dikutub selatan', 'sikutub selatan', 'kutub selatan tempatnya beradadi tega-tega antartika', 'adalah di kutub selatan', 'kutub selatan', 'di kutub selatan', 'kutub selatan, suhu rata rata bulan januari adalah dibawah 28 drajay celsius c biasa ditulis -280', 'kutub selatan', 'adalah di kutub selatan suhu rata-rata pada -89c', 'dikutub selatan', 'kutub selatan', 'dikutub selatan', 'kutub selatan', 'di kutub selatan', 'karna antartika diselimuti es setebal 1.500 meter atau lebih', 'blank', 'kutub selatan', 'selalu lebih ingin dari pada apa yang kita bayangkan termasuk pada musim panas sekalipun bagian yang paling dingin', 'kutub selatan', 'kutub selatan', 'bisa terjadi 89 c', 'di kutub selatan', 'kutub selatan', 'dikutub selatan', 'di kutub selatan', 'pada musim dingin bulan april sampai september suhu rata rata di kutub selatan bisa mencapai -89 derajat celcius', 'berangin dan kering', 'kutub selatan', 'kutub selatan suhu rata-ratanya -28 celcius', 'pada musim dingin bulan april sampai september suhu rata rata di kutub selatan bisa mencapai -89c', 'kutub selatan', 'kutub selatan', 'kutub selatan', 'di kutub selatan', 'di antartika', 'antartika selatan', 'atrika benua', 'kutub selatan ', 'kutub selatan', 'kutub selatan', 'di salju', 'bagian yang paling dingin kutub salah satu suhu rata-rata pada', 'kutub selatan', 'yang paling dingin bagian antartika bagian kutub selatan', 'nama peserta nama sekolah', 'kutub selatan tepatnya berada di tengah tengah antartika', 'bagian yang dingin', 'kutub utara', 'yang diselimuti es setebal 1500 meter atau lebih', 'aseh, nipas, es, air', 'bagian yang paling dingin adalah kutub selatan', 'adalah di kutub selatan', 'bagian selatan', 'kutub selatan', 'bagian antartika yang paling dingin adalah kutub selatan', 'antartika benua', 'antartika adalah benua yang terdingin', 'permukaan es', 'kutub selatan', 'berangin', 'di kutu selatan', 'di kutub selatan', 'yang paling dingin 1.500', 'kutub selatan', 'yang terdingin,terkering,tertinggi dan paling berangin', 'kutup selatan', 'kutup selatan', 'kutub selatan', 'kutup selatan', 'selatan', 'kutub selatan tempatnya di tengah tengah antartika', 'berada di tengah tengah antartika', 'di selatan', 'kutup selatan', 'kutub selatan', 'pinguin', 'bagisan yang paling dingin adalah di kutub selatan ', 'kutub selatan suhu rata rata pada bulan januari', 'bagian selatan ', 'diantara antartika', 'dingin dan air yang dingin ', 'kutub selatan', 'antartika benua', 'bagian antartika yang paling dingin adala kutub selatan', 'kutub selatan', 'di kutub selatan', 'kutub selatan', 'di bagian kutub selatan ', 'kutub selatan', 'kutub selatan', 'antartika yang paling dingin adalah kutub selatan ', 'cuaca', 'kutub selatan', 'kutb selatan', 'bagian kutub selatan', 'kutub selatan', 'kutub selatan', 'kutub selatan', 'bagian bawah', 'antartika', 'bagian antartika yang paling dingin adalah kutub selatan', 'benua yg berada di belah bumi selatan', 'kutub selatan', 'kutup selatan', 'kutub selatan', 'kutub selatan', 'kutub selatan ', 'bagian yang paling  ...

# %%
#stop iteration all rows
for i in range (len(sheet1)):
    #print(sheet1[i])
    stopsheet1.append(stopword.remove(str(sheet1[i])))
#print(nsheet1)
print("---------------------------------------------------")
# Out:
# ---------------------------------------------------

# %%
#steeming
factory = StemmerFactory()
stemmer = factory.create_stemmer()
for i in range (len(stopsheet1)):
    #print(sheet1[i])
    steemsheet1.append(stemmer.stem(str(stopsheet1[i])))
#print(nsheet1)
#print(type(nsheet1))
df=pd.DataFrame({'jawaban':steemsheet1})
print(df)
# Out:
#                                                jawaban
# 0                                   bagi kutub selatan
# 1                          paling dingin kutub selatan
# 2                                        kutub selatan
# 3                 kutub selatan tepat di tengah tengah
# 4                                        kutub selatan
# 5                                        kutub selatan
# 6                                        kutub selatan
# 7                                        kutub selatan
# 8                                        kutub selatan
# 9    kutub selatan suhu rata bulan januari tengah m...
# 10                                ada tengah antartika
# 11                                       kutub selatan
# 12              antarika benua yg dingin kering tinggi
# 13                                       kutub selatan
# 14                                 aldah kutup selatan
# 15                                       kutup selatan
# 16                                       kutub selatan
# 17                                       kutub selatan
# 18                                         basah angin
# 19                                       kutub selatan
# 20                                       kutup selatan
# 21               bulan april september jadi balik jadi
# 22                                               blank
# 23                                       kutub selatan
# 24     kutuk selatan tepat ada tengah tengah antartika
# 25                                       kutub selatan
# 26                                       kutub selatan
# 27   antartika selalu dingin apa yg bayang masuk mu...
# 28                                       kutub selatan
# 29                                       kutub selatan
# ..                                                 ...
# 583                                 bagi kutub selatan
# 584                                      kutub selatan
# 585                                 bagi kutub selatan
# 586  antartika selalu lebih dingin apa kita bayang ...
# 587  kutub selatan suhu rata rata tengah musim pana...
# 588  kutub selatan suhu rata rata bulan januari ten...
# 589                                      kutub selatan
# 590                                      kutub selatan
# 591                      tepat tengah tengah antartika
# 592                                      kutub selatan
# 593                bagi paling dingin di kutub selatan
# 594                                      kutub selatan
# 595                     paling dingin di kutub selatan
# 596                                      kutub selatan
# 597                                      kutub selatan
# 598                                      kutub selatan
# 599                        kutub selatan paling dingin
# 600  kutub selatan suhu rata tulis di bawah 28 celcius
# 601                                      kutub selatan
# 602                                      kutub selatan
# 603                                      kutub selatan
# 604                                      kutub selatan
# 605                                      belah selatan
# 606                         seluruh muka bumi limut es
# 607                        paling dingin kutub selatan
# 608                                      kutub selatan
# 609              kutub selatan tengah tengah antartika
# 610                                  ada kutub selatan
# 611                                      kutub selatan
# 612        kutub selatatan tempat ada tengah antartika
#
# [613 rows x 1 columns]

# %%
#Tokenization
#print(nnsheet1[611])
#print(nnsheet1[1].split)

tokensheet1=[words for segments in steemsheet1 for words in segments.split()]
print(tokensheet1)
# Out:
# ['bagi', 'kutub', 'selatan', 'paling', 'dingin', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'tepat', 'di', 'tengah', 'tengah', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'suhu', 'rata', 'bulan', 'januari', 'tengah', 'musim', 'panas', '-28', 'derajat', 'celcius', 'ada', 'tengah', 'antartika', 'kutub', 'selatan', 'antarika', 'benua', 'yg', 'dingin', 'kering', 'tinggi', 'kutub', 'selatan', 'aldah', 'kutup', 'selatan', 'kutup', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'basah', 'angin', 'kutub', 'selatan', 'kutup', 'selatan', 'bulan', 'april', 'september', 'jadi', 'balik', 'jadi', 'blank', 'kutub', 'selatan', 'kutuk', 'selatan', 'tepat', 'ada', 'tengah', 'tengah', 'antartika', 'kutub', 'selatan', 'kutub', 'selatan', 'antartika', 'selalu', 'dingin', 'apa', 'yg', 'bayang', 'masuk', 'musim', 'panas', 'bagi', 'baah', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'sikutub', 'selatan', 'kutub', 'selatan', 'tempat', 'adad', 'tega', 'antartika', 'di', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'suhu', 'rata', 'rata', 'bulan', 'januari', 'bawah', '28', 'drajay', 'celsius', 'c', 'biasa', 'tulis', '-280', 'kutub', 'selatan', 'di', 'kutub', 'selatan', 'suhu', 'rata', '-89c', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'karna', 'antartika', 'limut', 'es', 'setebal', '1', '500', 'meter', 'lebih', 'blank', 'kutub', 'selatan', 'selalu', 'lebih', 'dari', 'apa', 'kita', 'bayang', 'masuk', 'musim', 'panas', 'sekalipun', 'bagi', 'paling', 'dingin', 'kutub', 'selatan', 'kutub', 'selatan', 'jadi', '89', 'c', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'musim', 'dingin', 'bulan', 'april', 'september', 'suhu', 'rata', 'rata', 'kutub', 'selatan', 'capai', '-89', 'derajat', 'celcius', 'angin', 'kering', 'kutub', 'selatan', 'kutub', 'selatan', 'suhu', 'rata', '-28', 'celcius', 'musim', 'dingin', 'bulan', 'april', 'september', 'suhu', 'rata', 'rata', 'kutub', 'selatan', 'capai', '-89c', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'antartika', 'antartika', 'selatan', 'atrika', 'benua', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'salju', 'bagi', 'paling', 'dingin', 'kutub', 'salah', 'satu', 'suhu', 'rata', 'kutub', 'selatan', 'paling', 'dingin', 'bagi', 'antartika', 'bagi', 'kutub', 'selatan', 'nama', 'serta', 'nama', 'sekolah', 'kutub', 'selatan', 'tepat', 'ada', 'tengah', 'tengah', 'antartika', 'bagi', 'dingin', 'kutub', 'utara', 'limut', 'es', 'setebal', '1500', 'meter', 'lebih', 'aseh', 'nipas', 'es', 'air', 'bagi', 'paling', 'dingin', 'kutub', 'selatan', 'di', 'kutub', 'selatan', 'bagi', 'selatan', 'kutub', 'selatan', 'bagi', 'antartika', 'paling', 'dingin', 'kutub', 'selatan', 'antartika', 'benua', 'antartika', 'benua', 'dingin', 'muka', 'es', 'kutub', 'selatan', 'angin', 'kutu', 'selatan', 'kutub', 'selatan', 'paling', 'dingin', '1', '500', 'kutub', 'selatan', 'dingin', 'kering', 'tinggi', 'paling', 'angin', 'kutup', 'selatan', 'kutup', 'selatan', 'kutub', 'selatan', 'kutup', 'selatan', 'selatan', 'kutub', 'selatan', 'tempat', 'tengah', 'tengah', 'antartika', 'ada', 'tengah', 'tengah', 'antartika', 'selatan', 'kutup', 'selatan', 'kutub', 'selatan', 'pinguin', 'bagisan', 'paling', 'dingin', 'di', 'kutub', 'selatan', 'kutub', 'selatan', 'suhu', 'rata', 'rata', 'bulan', 'januari', 'bagi', 'selatan', 'antara', 'antartika', 'dingin', 'air', 'dingin', 'kutub', 'selatan', 'antartika', 'benua', 'bagi', 'antartika', 'paling', 'dingin', 'adala', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'bagi', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'antartika', 'paling', 'dingin', 'kutub', 'selatan', 'cuaca', 'kutub', 'selatan', 'kutb', 'selatan', 'bagi', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'sel ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(tokensheet1)
tf = vec.fit_transform(sheet1.values.astype('U'))
BagofWord= vec.get_feature_names()
print(BagofWord)

#Binary feature extraction
print(tf)
# Out:
# ['0c', '1500', '28', '280', '29', '500', '89', '89c', 'ada', 'adala', 'adalah', 'agar', 'air', 'airnya', 'akan', 'aku', 'aldah', 'angin', 'antarika', 'antartik', 'antartika', 'antartikik', 'apa', 'april', 'aseh', 'atau', 'atrika', 'baah', 'bagai', 'bagaian', 'bagain', 'bagian', 'bagisan', 'bahan', 'banyak', 'barangngin', 'basah', 'basaha', 'baso', 'bawah', 'bayangkan', 'belah', 'belahan', 'benua', 'berada', 'beradadi', 'berangin', 'beras', 'berawan', 'berda', 'berkelompok', 'bermasak', 'bersengkak', 'beua', 'biasa', 'bisa', 'blank', 'bola', 'bulan', 'bulkan', 'bulu', 'bumi', 'bunyaka', 'celcius', 'celsius', 'ciantartika', 'cuaca', 'dalam', 'dan', 'dari', 'daripada', 'derajat', 'di', 'diangin', 'diantara', 'diantartika', 'dibagian', 'dibawah', 'dibulan', 'didalam', 'digunung', 'dikutb', 'dikutub', 'dikutup', 'dingin', 'dipaling', 'disana', 'diselimuti', 'ditengah', 'ditulis', 'drajay', 'dunia', 'es', 'gunung', 'hampir', 'hangat', 'harus', 'hidup', 'ialah', 'ilmuwan', 'ingin', 'ini', 'itu', 'jakarta', 'januari', 'jenis', 'jepang', 'jika', 'jupiter', 'kadang', 'kamu', 'karna', 'kejadian', 'kerin', 'kering', 'kia', 'kita', 'kolam', 'kuktub', 'kurub', 'kutb', 'kutib', 'kutp', 'kuttub', 'kutu', 'kutub', 'kutud', 'kutuk', 'kutup', 'lain', 'lapisan', 'lebih', 'lemari', 'luas', 'luasnya', 'mana', 'melakukan', 'menambah', 'mencapai', 'mencari', 'mencoba', 'menemukannya', 'menemumkannya', 'menggunakan', 'mereka', 'meter', 'musim', 'nama', 'nan', 'nipas', 'orang', 'pad', 'pada', 'paling', 'panas', 'para', 'pelanet', 'pendingin', 'penelitiannya', 'permukaan', 'peserta', 'pinguin', 'rasa', 'rat', 'rata', 'ratanya', 'salah', 'salju', 'sampai', 'sangat', 'sangt', 'sangtlah', 'satu', 'sebalah', 'sebaliknya', 'sebelah', 'sedengin', 'sedingin', 'segelas', 'sekali', 'sekalipun', 'sekatan', 'sekolah', 'selalu', 'selatan', 'selatatan', 'seletan', 'seluruh', 'seper', 'sepersepuluh', 'seperti', 'september', 'sepuluh', 'setebal', 'setelah', 'sikutub', 'suhu', 'suku', 'tega', 'tempat', 'tempatnya', 'tenga', 'tengah', 'tengan', 'tepatnya', 'terbaca', 'terdingin', 'terjadi', 'terkering', 'termasuk', 'tertinggi', 'tetap', 'tidak', 'tinggi', 'tulis', 'untuk', 'utara', 'wan', 'wool', 'yaitu', 'yang', 'yg']
#   (0, 184)	1
#   (0, 125)	1
#   (0, 31)	1
#   (0, 72)	1
#   (1, 84)	1
#   (1, 153)	1
#   (1, 220)	1
#   (1, 184)	1
#   (1, 125)	1
#   (1, 72)	1
#   (2, 184)	1
#   (2, 125)	1
#   (2, 72)	1
#   (3, 202)	2
#   (3, 8)	1
#   (3, 204)	1
#   (3, 184)	1
#   (3, 125)	1
#   (3, 72)	1
#   (4, 184)	1
#   (4, 125)	1
#   (5, 184)	1
#   (5, 125)	1
#   (6, 184)	1
#   (6, 125)	1
#   :	:
#   (607, 10)	1
#   (607, 84)	1
#   (607, 153)	1
#   (607, 220)	1
#   (607, 184)	1
#   (607, 125)	1
#   (608, 82)	1
#   (608, 184)	1
#   (609, 20)	1
#   (609, 202)	2
#   (609, 184)	1
#   (609, 125)	1
#   (609, 72)	1
#   (610, 82)	1
#   (610, 44)	1
#   (610, 184)	1
#   (611, 184)	1
#   (611, 125)	1
#   (612, 185)	1
#   (612, 88)	1
#   (612, 200)	1
#   (612, 20)	1
#   (612, 44)	1
#   (612, 202)	1
#   (612, 125)	1

# %%
from sklearn.feature_extraction.text import TfidfTransformer
transformer = TfidfTransformer(smooth_idf=False)
tfidf = transformer.fit_transform(binary)

#tfidf feature extraction
print(tfidf)
# Out:
#   (0, 72)	0.553335518551253
#   (0, 31)	0.718787450997864
#   (0, 125)	0.3178350481079092
#   (0, 184)	0.27594435379592847
#   (1, 72)	0.3533826774559091
#   (1, 125)	0.20298245191953496
#   (1, 184)	0.1762293424224015
#   (1, 220)	0.5120514922458839
#   (1, 153)	0.5388272203022004
#   (1, 84)	0.5003304131335233
#   (2, 72)	0.7959029470920015
#   (2, 125)	0.4571653960340917
#   (2, 184)	0.3969109465349359
#   (3, 72)	0.20899698480345663
#   (3, 125)	0.12004753805310227
#   (3, 184)	0.10422525932888488
#   (3, 204)	0.4260901044911014
#   (3, 8)	0.5707730408478733
#   (3, 202)	0.6509311046219206
#   (4, 125)	0.7551157899607838
#   (4, 184)	0.6555914457586381
#   (5, 125)	0.7551157899607838
#   (5, 184)	0.6555914457586381
#   (6, 72)	0.7959029470920015
#   (6, 125)	0.4571653960340917
#   :	:
#   (607, 125)	0.18802286002393678
#   (607, 184)	0.1632414263846456
#   (607, 220)	0.47431383915768965
#   (607, 153)	0.4991162243922888
#   (607, 84)	0.46345659117180715
#   (607, 10)	0.4991162243922888
#   (608, 184)	0.29010537036170597
#   (608, 82)	0.9569947095398684
#   (609, 72)	0.27608340935321196
#   (609, 125)	0.15858187438124113
#   (609, 184)	0.1376807658890459
#   (609, 202)	0.8598749823451993
#   (609, 20)	0.3745514138789066
#   (610, 184)	0.19811892503470674
#   (610, 44)	0.7304926381406636
#   (610, 82)	0.6535513730116292
#   (611, 125)	0.7551157899607838
#   (611, 184)	0.6555914457586381
#   (612, 125)	0.11118176736073171
#   (612, 202)	0.3014292163572957
#   (612, 44)	0.35591245025866897
#   (612, 20)	0.26259803224676587
#   (612, 200)	0.4196537477593148
#   (612, 88)	0.43014967460079867
#   (612, 185)	0.5831034494634345
