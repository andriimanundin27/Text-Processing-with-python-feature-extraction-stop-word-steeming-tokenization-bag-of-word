# %%
import pandas as pd
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import word_tokenize

# Assign spreadsheet filename to `file`
data='F:/DS/H/respon.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(data)

# Print the sheet names
#print(xl.sheet_names)

# Load a sheet into a DataFrame by name: df1
df1 = xl.parse('Pertanyaan 1', skiprows=1)
#df1 = xl.parse('Pertanyaan 3', skiprows=1)
#df1 = xl.parse('Pertanyaan 4')
#df1 = xl.parse('Pertanyaan 7')
#df1 = xl.parse('Pertanyaan 8')
#df1 = xl.parse('Pertanyaan 10')

print(df1.Jawaban)
# Out:
# 0                        PADA BAGIAN BAWAH BUMI SELATAN
# 1      KAMU DAPAT MENEMUKAN ANTARTIKA DALAM BOLA DUNI...
# 2      KITA DAPAT MENEMUKANNYA DI BAGIAN BAWAH BOLA D...
# 3                               DI BAGIAN BAWAH SELATAN
# 4                            DI TENGAH TENGAH ANTARTIKA
# 5                                          BAGIAN BAWAH
# 6                                      DI KUTUB SELATAN
# 7                                        DIKUTUB SELATAN
# 8                                         KUTUB SELATAN
# 9      ANTARTIKA BERADA DIBELAHAN BUMI SELATAN DI TEM...
# 10         ANTARTIKA DALAM BOLA DUNIA DI SEBELAH SELATAN
# 11                     KITA MENEMUKANNYA DI BAGIAN BAWAH
# 12                                         SEBELAH TIMUR
# 13                                  BELAHAN BUMI SELATAN
# 14       BAGIAN YG PALING DINGIN ADALAH DI KUTUP SELATAN
# 15                                               AMERIKA
# 16                                  BELAHAN BUMI SELATAN
# 17     PADA BAGIAN BAWAH, YANG BERADA DIBELAHAN BUMI ...
# 18                                          DARI SEBELAH
# 19                                     PADA BAGIAN BAWAH
# 20                                               DIBAWAH
# 21     SELATAN SUHU YG RATA-RATA PADA BULAN JANUARI D...
# 22                                 BELAHAN BUMI SELATAN
# 23                               DI BELAHAN BUMI SELATAN
# 24     BENUA YG BERADA DI BELAGAN BUNI SELATAN (PADA ...
# 25                                     PADA BAGIAN BAWAH
# 26                                                BAWAH
# 27     BELAHAN BUMI SELATAN. JIKA KAMU MENCOBA MENCAR...
# 28                                                 BARAT
# 29     DISEBELAH KUTUB SELATAN TEMPATNYA BERADA DITEN...
#                              ...
# 583                                     DI BAGIAN BAWAH
# 584                                   PADA BAGIAN BAWAH
# 585                                 BAGIAN PALING BAWAH
# 586    JUMLAH PINGWIN LEBIH BANYAK DI ANTARTIKA DI BA...
# 587    PADA BAGIAN BAWAH LUASNYA HAMPIR SEPERSEPULUH ...
# 588                                   PADA BAGIAN BAWAH
# 589                                        BUMI SELATAN
# 590                                        BAGIAN BAWAH
# 591                             DI SEBELAH BAGIAN BAWAH
# 592                                    PADA BAGIAN BAWAH
# 593                   DI BAGIAN BAWAH BOLA DUNIA (GLOBE)
# 594                                      DU BELAHAN BUMI
# 595                LETAK ANTARTIKA ADA PADA BAGIAN BAWAH
# 596                                      DI BAGIAN BAWAH
# 597                                DI BAGIAN BAWAH GLOBE
# 598                                         BAGIAN BAWAH
# 599    JIKA KAMU MENCOBA MENCARI DI DALAM BOLA DUNIA ...
# 600                           DI BELAH BAGIAN BAWAH BUMI
# 601                                       DIBAGIAN BAWAH
# 602                                      DI BAGIAN BAWAH
# 603                               DISEBELAH BAGIAN BAWAH
# 604                                    PADA BAGIAN BAWAH
# 605    ANTARTIKA ADALAH BENUA YANG BERADA DI BELAHAN ...
# 606                                        KUTUB SELATAN
# 607    KI8TA DAPAT MENEMUKAN ANTARTIKA DIBAGIAN DI BA...
# 608                                        BAGIAN BAWAH
# 609                                         BAGIAN BAWAH
# 610                     BERADA DITENGAH-TENGAH ANTARTIKA
# 611                       DISEBELAH BELAHAN BUMI SELATAN
# 612                       BERADA DI BELAHAN BUMI SELATAN
# Name: Jawaban, Length: 613, dtype: object

# %%
#emptyarray for pre-processing
stopsheet1=[]
steemsheet1=[]

# %%
#select coloum jawaban
sheet1 = df1.Jawaban

#stopword
 
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
#print(stopwords)

#lowercase
sheet1=sheet1.str.lower()
#print(type(sheet1))

sheetray=sheet1.tolist()
print(sheetray)

#print(type(sheet1))
#print(sheet1[1])
# Out:
# ['pada bagian bawah bumi selatan ', 'kamu dapat menemukan antartika dalam bola dunia (globe) di bawah', 'kita dapat menemukannya di bagian bawah bola dunia ', 'di bagian bawah selatan ', 'di tengah tengah antartika ', 'bagian bawah ', 'di kutub selatan ', 'dikutub selatan', 'kutub selatan ', 'antartika berada dibelahan bumi selatan di temukan pada bagian bawah bola ,dunia(globe)', 'antartika dalam bola dunia di sebelah selatan', 'kita menemukannya di bagian bawah', 'sebelah timur', 'belahan bumi selatan', 'bagian yg paling dingin adalah di kutup selatan', 'amerika', 'belahan bumi selatan', 'pada bagian bawah, yang berada dibelahan bumi selatan', 'dari sebelah', 'pada bagian bawah', 'dibawah', 'selatan suhu yg rata-rata pada bulan januari di tengah tengah musim panas', 'belahan bumi selatan ', 'di belahan bumi selatan', 'benua yg berada di belagan buni selatan (pada bagian di bawah)', 'pada bagian bawah', 'bawah ', 'belahan bumi selatan. jika kamu mencoba mencari dalam bola dunia kamu akan menemukannya', 'barat', 'disebelah kutub selatan tempatnya berada ditengah-tengah antartika.', 'di bagian bawah bola dunia globe', 'daratan es', 'dibagian bawah ', 'diselurh permukaan bumi dan diselimuti es setebal 1500 meter atau lebih', 'benua yang berada di belah bumi selatan jika kamu mencoba mecar du dalam bola', 'di sebelah kutub selatan', 'bagian bawah', 'jika kamu mencoba mencari di dalam bola dunia, kamu akan menemukan pada bagian bawah', 'bagian bawah', 'jika kamu mencoba mencari dalam bola dunia kamu akan menemukan pada bagian bawah', 'disebelah selatan', 'pada bagian bawah', 'pada bagian bawah', 'belahan bumi selatan', 'kamu akan menemukannya pada bagian bawah', 'antartika adalah benua yang berada di belahan bumi selatan', 'blank', 'pada bagian bawah', 'disebelah kiri kami menemukan  antartika bola', 'belahan bumi selatan', 'pada bagian bawah', 'biasa tulikan 28c', 'pada bagian bawah', 'kutub selatan', 'disebelah selatan', 'di bagian bawah globe', 'blank', 'kering dan berawan', 'pada bagian bawah', 'kutub selatan tepatnya berada di tengah-tengah antartika', 'antartika adalah benua yang berada di belahan bumi selatan', 'kutub selatan', 'belahan bumi selatan', 'pada bagian bawah bola dunia (globe)', 'bawah', 'batu-batu', 'pada bawah', 'di cari dengan bola globe yg luasnya 1500 meter atau lebih', 'di bagian bawah ', 'bagian bawah', 'belahan bumi selatan', 'kanan', 'diantarika selalu lebih dingin penelitiannya tetap lebih angat', 'seluruh permukaan bumi dan diselumuti es setebal 1500 meter', 'saya dapat menemukan antartika dalam bola dunia di sebelah barat', 'mereka pasti menang setelah main bola dunia', 'pada bagian bawah globe', 'tulisan tidak terbaca', 'kutub selatan', 'bumi selatan di bagian bawah', 'baket, bulat, loda, pesil', 'di kutub selatan', 'ada kamu akan menemukan ada bagian bawah', 'selatan pada bagian bawah', 'tepatnya di tengah-tengah antartika', 'saya bisa menemukan antartika itu di bagian bawah bola dunia', 'pada bagian bawah', 'jika kamu mencoba mencari di dalam bola dunia', 'bahasa indonesianya peta.', 'belahan bumi selatan', 'tanpatnya berada ditengah-tengah antartika', 'pada bagian bumi', 'kutub selatan', 'sebalah kiri', 'pada bagian bawah', 'di belahan bumi selatan', 'belahan bumi selatan', 'bagian bawah', 'bawah', 'tidak setuju sebenarnya dia mengirimkan makanan segar', 'kutub selatan', 'blank', 'berada di belahan bumi selatan', 'belah bumi selatan mencari di dalam bola dunia', 'selatan', 'di bagian bawah', 'kamu akan menemukanys psds bsgisn bawah', 'jika kamu mencoba mencari didalam bola dunia kamu akan menemukan pada bagian bawah ', 'menemukan pada bagian bawah ', 'di belah benua yg berada di belah bumi selatan ', 'di selatan', 'dengan membaca surat kepada keponakan daniel', 'pada bagian bawah', 'pada bagian bawah', 'kamu dapat menemukan antartika dalam bola dunia (globe)disebelah bagian bawah', 'dibelahan bumi selatan', 'bawah', 'dibagian bawah', 'pada bagian bawah ', 'di bawah', 'kamu akan menemukannya pada  ...

# %%
#stop iteration all rows
for i in range (len(sheet1)):
    #print(sheet1[i])
    stopsheet1.append(stopword.remove(str(sheet1[i])))
#print(nsheet1)
print("---------------------------------------------------")
# Out:
# ---------------------------------------------------

# %%
#steeming
factory = StemmerFactory()
stemmer = factory.create_stemmer()
for i in range (len(stopsheet1)):
    #print(sheet1[i])
    steemsheet1.append(stemmer.stem(str(stopsheet1[i])))
#print(nsheet1)
#print(type(nsheet1))
df=pd.DataFrame({'jawaban':steemsheet1})
print(df)
# Out:
#                                                jawaban
# 0                              bagi bawah bumi selatan
# 1           kamu temu antartika bola dunia globe bawah
# 2                     dapat temu bagi bawah bola dunia
# 3                                   bagi bawah selatan
# 4                              tengah tengah antartika
# 5                                           bagi bawah
# 6                                        kutub selatan
# 7                                        kutub selatan
# 8                                        kutub selatan
# 9    antartika ada belah bumi selatan temu bagi baw...
# 10                  antartika bola dunia belah selatan
# 11                                     temu bagi bawah
# 12                                         belah timur
# 13                                  bahan bumi selatan
# 14              bagi yg paling dingin di kutup selatan
# 15                                             amerika
# 16                                  bahan bumi selatan
# 17                   bagi bawah ada belah bumi selatan
# 18                                               belah
# 19                                          bagi bawah
# 20                                               bawah
# 21   selatan suhu yg rata bulan januari tengah teng...
# 22                                  bahan bumi selatan
# 23                                  bahan bumi selatan
# 24     benua yg ada bagan buni selatan pada bagi bawah
# 25                                          bagi bawah
# 26                                               bawah
# 27   bahan bumi selatan kamu coba cari bola dunia k...
# 28                                               barat
# 29     belah kutub selatan tempat ada tengah antartika
# ..                                                 ...
# 583                                         bagi bawah
# 584                                         bagi bawah
# 585                                  bagi paling bawah
# 586  jumlah pingwin lebih banyak antartika banding ...
# 587  bagi bawah luas hampir puluh seluru muka bumi ...
# 588                                         bagi bawah
# 589                                       bumi selatan
# 590                                         bagi bawah
# 591                                   belah bagi bawah
# 592                                         bagi bawah
# 593                        bagi bawah bola dunia globe
# 594                                      du bahan bumi
# 595                    letak antartika pada bagi bawah
# 596                                         bagi bawah
# 597                                   bagi bawah globe
# 598                                         bagi bawah
# 599  kamu coba cari dalam bola dunia kamu temu bgia...
# 600                              belah bagi bawah bumi
# 601                                         bagi bawah
# 602                                         bagi bawah
# 603                                   belah bagi bawah
# 604                                         bagi bawah
# 605             antartika benua ada bahan bumi selatan
# 606                                      kutub selatan
# 607         ki8ta temu antartika bagi bawah bola dunia
# 608                                         bagi bawah
# 609                                         bagi bawah
# 610                               ada tengah antartika
# 611                           belah bahan bumi selatan
# 612                             ada bahan bumi selatan
#
# [613 rows x 1 columns]

# %%
#Tokenization
#print(nnsheet1[611])
#print(nnsheet1[1].split)

tokensheet1=[words for segments in steemsheet1 for words in segments.split()]
print(tokensheet1)
# Out:
# ['bagi', 'bawah', 'bumi', 'selatan', 'kamu', 'temu', 'antartika', 'bola', 'dunia', 'globe', 'bawah', 'dapat', 'temu', 'bagi', 'bawah', 'bola', 'dunia', 'bagi', 'bawah', 'selatan', 'tengah', 'tengah', 'antartika', 'bagi', 'bawah', 'kutub', 'selatan', 'kutub', 'selatan', 'kutub', 'selatan', 'antartika', 'ada', 'belah', 'bumi', 'selatan', 'temu', 'bagi', 'bawah', 'bola', 'dunia', 'globe', 'antartika', 'bola', 'dunia', 'belah', 'selatan', 'temu', 'bagi', 'bawah', 'belah', 'timur', 'bahan', 'bumi', 'selatan', 'bagi', 'yg', 'paling', 'dingin', 'di', 'kutup', 'selatan', 'amerika', 'bahan', 'bumi', 'selatan', 'bagi', 'bawah', 'ada', 'belah', 'bumi', 'selatan', 'belah', 'bagi', 'bawah', 'bawah', 'selatan', 'suhu', 'yg', 'rata', 'bulan', 'januari', 'tengah', 'tengah', 'musim', 'panas', 'bahan', 'bumi', 'selatan', 'bahan', 'bumi', 'selatan', 'benua', 'yg', 'ada', 'bagan', 'buni', 'selatan', 'pada', 'bagi', 'bawah', 'bagi', 'bawah', 'bawah', 'bahan', 'bumi', 'selatan', 'kamu', 'coba', 'cari', 'bola', 'dunia', 'kamu', 'temu', 'barat', 'belah', 'kutub', 'selatan', 'tempat', 'ada', 'tengah', 'antartika', 'bagi', 'bawah', 'bola', 'dunia', 'globe', 'darat', 'es', 'bagi', 'bawah', 'diselurh', 'muka', 'bumi', 'limut', 'es', 'setebal', '1500', 'meter', 'lebih', 'benua', 'ada', 'belah', 'bumi', 'selatan', 'kamu', 'coba', 'mecar', 'du', 'bola', 'belah', 'kutub', 'selatan', 'bagi', 'bawah', 'kamu', 'coba', 'cari', 'dalam', 'bola', 'dunia', 'kamu', 'temu', 'bagi', 'bawah', 'bagi', 'bawah', 'kamu', 'coba', 'cari', 'bola', 'dunia', 'kamu', 'temu', 'bagi', 'bawah', 'belah', 'selatan', 'bagi', 'bawah', 'bagi', 'bawah', 'bahan', 'bumi', 'selatan', 'kamu', 'temu', 'bagi', 'bawah', 'antartika', 'benua', 'ada', 'bahan', 'bumi', 'selatan', 'blank', 'bagi', 'bawah', 'belah', 'kiri', 'temu', 'antartika', 'bola', 'bahan', 'bumi', 'selatan', 'bagi', 'bawah', 'biasa', 'tuli', '28c', 'bagi', 'bawah', 'kutub', 'selatan', 'belah', 'selatan', 'bagi', 'bawah', 'globe', 'blank', 'kering', 'awan', 'bagi', 'bawah', 'kutub', 'selatan', 'tepat', 'ada', 'tengah', 'antartika', 'antartika', 'benua', 'ada', 'bahan', 'bumi', 'selatan', 'kutub', 'selatan', 'bahan', 'bumi', 'selatan', 'bagi', 'bawah', 'bola', 'dunia', 'globe', 'bawah', 'batu', 'bawah', 'cari', 'bola', 'globe', 'yg', 'luas', '1500', 'meter', 'lebih', 'bagi', 'bawah', 'bagi', 'bawah', 'bahan', 'bumi', 'selatan', 'kanan', 'diantarika', 'selalu', 'lebih', 'dingin', 'teliti', 'tetap', 'lebih', 'angat', 'seluruh', 'muka', 'bumi', 'lumut', 'es', 'setebal', '1500', 'meter', 'dapat', 'temu', 'antartika', 'bola', 'dunia', 'belah', 'barat', 'pasti', 'menang', 'main', 'bola', 'dunia', 'bagi', 'bawah', 'globe', 'tulis', 'baca', 'kutub', 'selatan', 'bumi', 'selatan', 'bagi', 'bawah', 'baket', 'bulat', 'loda', 'sil', 'kutub', 'selatan', 'kamu', 'temu', 'bagi', 'bawah', 'selatan', 'bagi', 'bawah', 'tepat', 'tengah', 'antartika', 'bisa', 'temu', 'antartika', 'di', 'bagi', 'bawah', 'bola', 'dunia', 'bagi', 'bawah', 'kamu', 'coba', 'cari', 'dalam', 'bola', 'dunia', 'bahasa', 'indonesia', 'peta', 'bahan', 'bumi', 'selatan', 'tanpatnya', 'ada', 'tengah', 'antartika', 'bagi', 'bumi', 'kutub', 'selatan', 'seba', 'kiri', 'bagi', 'bawah', 'bahan', 'bumi', 'selatan', 'bahan', 'bumi', 'selatan', 'bagi', 'bawah', 'bawah', 'tuju', 'benar', 'kirim', 'makan', 'segar', 'kutub', 'selatan', 'blank', 'ada', 'bahan', 'bumi', 'selatan', 'belah', 'bumi', 'selatan', 'cari', 'dalam', 'bola', 'dunia', 'selatan', 'bagi', 'bawah', 'kamu', 'menemukanys', 'psds', 'bsgisn', 'bawah', 'kamu', 'coba', 'cari', 'dalam', 'bola', 'dunia', 'kamu', 'temu', 'bagi', 'bawah', 'temu', 'bagi', 'bawah', 'belah', 'benua', 'yg', 'ada', 'belah', 'bumi', 'selatan', 'selatan', 'baca', 'surat', 'keponakan', 'daniel', 'bagi', 'bawah', 'bagi', 'bawah', 'kamu', 'temu', 'antartika', 'bola', 'dunia', 'globe', 'belah', 'bagi', 'bawah', 'belah', 'bumi', 'selatan', 'bawah', 'bagi', 'bawah', 'bagi', 'bawah', 'bawah', 'kamu', 'temu', 'bagi', 'bawah', 'aku', 'temu', 'antartika', 'antartika' ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(tokensheet1)
tf = vec.fit_transform(sheet1.values.astype('U'))
BagofWord= vec.get_feature_names()
print(BagofWord)

#Binary feature extraction
print(tf)
# Out:
# ['1500', '15000meter', '1500m', '1500meter', '1599', '28', '28c', '500', 'abagian', 'ada', 'adalah', 'adlah', 'afrika', 'ah', 'akan', 'aku', 'alam', 'amerika', 'angat', 'antarantika', 'antarika', 'antartika', 'apa', 'artinya', 'atau', 'ba', 'bagi', 'bagia', 'bagian', 'bahasa', 'baian', 'baket', 'balok', 'bandingkan', 'banyak', 'barat', 'batu', 'bawa', 'bawah', 'bawahnya', 'bawha', 'baya', 'bayangkantermasuk', 'belagan', 'belah', 'belahan', 'benua', 'berada', 'beradadi', 'berangin', 'berawan', 'bgian', 'biasa', 'bisa', 'blank', 'bola', 'bsgisn', 'bulan', 'bulat', 'bumi', 'buni', 'burung', 'cari', 'ceislus', 'celcius', 'daerah', 'dalam', 'dan', 'daniel', 'dapat', 'daratan', 'dari', 'daripada', 'daya', 'dengan', 'derajat', 'di', 'dia', 'dialamèóbola', 'diantarika', 'dibagian', 'dibawa', 'dibawah', 'dibebelah', 'dibelahan', 'didalam', 'dijawab', 'dikutub', 'dilihat', 'dingin', 'disebelah', 'diseblah', 'disebuah', 'diselimuti', 'diselumuti', 'diselurh', 'ditemukan', 'ditemuklan', 'ditenga', 'ditengah', 'ditulis', 'du', 'dudunia', 'duiantartika', 'duni', 'dunia', 'es', 'globe', 'gunung', 'hampir', 'hangat', 'hanya', 'ilmuwan', 'indonesianya', 'itu', 'januari', 'jenis', 'jika', 'jumlah', 'kalau', 'kami', 'kamu', 'kanan', 'karena', 'kepada', 'keponakan', 'kering', 'ki8ta', 'kiri', 'kita', 'kutub', 'kutup', 'lain', 'lainnya', 'langsung', 'lapanggan', 'laut', 'lebih', 'letak', 'loda', 'luas', 'luasnya', 'main', 'maka', 'makanan', 'mecar', 'memakan', 'membaca', 'memenuhi', 'memukanya', 'menang', 'mencari', 'mencoba', 'mendapatlan', 'menemukan', 'menemukankany', 'menemukannya', 'menemukanya', 'menemukanys', 'menghapus', 'mengirimkan', 'mereka', 'merupakan', 'meter', 'musim', 'nama', 'nan', 'nya', 'olang', 'pad', 'pada', 'paling', 'panas', 'pasti', 'penelitiannya', 'penguin', 'perlu', 'permukaan', 'persepuluh', 'pesawat', 'pesil', 'peta', 'pingwin', 'psds', 'rasa', 'rata', 'rumputnya', 'salatan', 'sampai', 'sanah', 'sara', 'saya', 'sebalah', 'sebelah', 'sebelahan', 'sebenarnya', 'sebulan', 'sedikit', 'segar', 'selalu', 'selatan', 'selimut', 'selimuti', 'seluasnya', 'selurh', 'seluru', 'seluruh', 'seperpuluhan', 'sepersepuluh', 'sepesepuluh', 'setebal', 'setelah', 'setuju', 'seyasa', 'suhu', 'sumber', 'surat', 'tanpatnya', 'tebal', 'televisi', 'tempatnya', 'temuka', 'temukan', 'tenga', 'tengah', 'tenhaj', 'tepat', 'tepatnya', 'terbaca', 'terbang', 'terdapat', 'terdingin', 'terkering', 'terpatnya', 'tertinggi', 'tetap', 'tidak', 'timur', 'tinggal', 'tulikan', 'tulisan', 'tumian', 'untuk', 'utara', 'vbagian', 'wheeler', 'yaitu', 'yang', 'yg', 'óuni', 'ôó9globe']
#   (0, 200)	1
#   (0, 59)	1
#   (0, 38)	1
#   (0, 28)	1
#   (0, 170)	1
#   (1, 76)	1
#   (1, 107)	1
#   (1, 105)	1
#   (1, 55)	1
#   (1, 66)	1
#   (1, 21)	1
#   (1, 154)	1
#   (1, 69)	1
#   (1, 121)	1
#   (1, 38)	1
#   (2, 156)	1
#   (2, 129)	1
#   (2, 76)	1
#   (2, 105)	1
#   (2, 55)	1
#   (2, 69)	1
#   (2, 38)	1
#   (2, 28)	1
#   (3, 76)	1
#   (3, 200)	1
#   :	:
#   (607, 80)	1
#   (607, 76)	1
#   (607, 105)	1
#   (607, 55)	1
#   (607, 21)	1
#   (607, 154)	1
#   (607, 69)	1
#   (607, 38)	1
#   (608, 38)	1
#   (608, 28)	1
#   (609, 38)	1
#   (609, 28)	1
#   (610, 99)	1
#   (610, 47)	1
#   (610, 224)	1
#   (610, 21)	1
#   (611, 90)	1
#   (611, 45)	1
#   (611, 200)	1
#   (611, 59)	1
#   (612, 45)	1
#   (612, 47)	1
#   (612, 76)	1
#   (612, 200)	1
#   (612, 59)	1

# %%
from sklearn.feature_extraction.text import TfidfTransformer
transformer = TfidfTransformer(smooth_idf=False)
tfidf = transformer.fit_transform(tf)

#tfidf feature extraction
print(tfidf)
# Out:
#   (0, 170)	0.4838129173329011
#   (0, 28)	0.3751206821396553
#   (0, 38)	0.3412028450725735
#   (0, 59)	0.5533239492093095
#   (0, 200)	0.4501363799991087
#   (1, 38)	0.13691234629626406
#   (1, 121)	0.31907353786606985
#   (1, 69)	0.4236955167137673
#   (1, 154)	0.36519832969113286
#   (1, 21)	0.2976178032721742
#   (1, 66)	0.3775707248887043
#   (1, 55)	0.29099530101985144
#   (1, 105)	0.2976178032721742
#   (1, 107)	0.3511000338204896
#   (1, 76)	0.19722451943474997
#   (2, 28)	0.17229261288998443
#   (2, 38)	0.1567141789349921
#   (2, 69)	0.4849752182067974
#   (2, 55)	0.33308237647601596
#   (2, 105)	0.3406627009028731
#   (2, 76)	0.22574938977514714
#   (2, 129)	0.5286367874864557
#   (2, 156)	0.3913315397669097
#   (3, 28)	0.4479270318173005
#   (3, 38)	0.40742615621517997
#   :	:
#   (607, 69)	0.39728337519802015
#   (607, 154)	0.3424327596423165
#   (607, 21)	0.27906503783675213
#   (607, 55)	0.2728553661662429
#   (607, 105)	0.27906503783675213
#   (607, 76)	0.1849300256008562
#   (607, 80)	0.31529461174462425
#   (607, 127)	0.58703532895314
#   (608, 28)	0.7397593960760109
#   (608, 38)	0.6728714854392742
#   (609, 28)	0.7397593960760109
#   (609, 38)	0.6728714854392742
#   (610, 21)	0.40501287640984673
#   (610, 224)	0.4969797651285403
#   (610, 47)	0.4404203455612178
#   (610, 99)	0.6284947113625863
#   (611, 59)	0.4116490113159688
#   (611, 200)	0.3348819367908624
#   (611, 45)	0.4894189532850438
#   (611, 90)	0.6920030838509019
#   (612, 59)	0.4086202723197672
#   (612, 200)	0.3324180174003128
#   (612, 76)	0.36297054049875854
#   (612, 47)	0.5956181468085165
#   (612, 45)	0.48581801600948504
